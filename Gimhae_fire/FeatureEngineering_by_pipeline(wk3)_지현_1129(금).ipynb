# %% [markdown]
# ## 1. 데이터, 패키지 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import OneHotEncoder, StandardScaler, FunctionTransformer

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer,IterativeImputer                          

from sklearn.compose import ColumnTransformer,make_column_transformer

from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge

# %%
train = pd.read_csv("PJT002_train.csv", encoding = 'utf8')
test = pd.read_csv("PJT002_test.csv", encoding = 'utf-8')
validation = pd.read_csv("PJT002_validation.csv", encoding = 'utf8')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (8,172,173,174,175,176,177,178,179) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## 2. 전처리

# %% [markdown]
# - 건물 승인일자 년 단위로 자르기 함수 (소수점 포함 10자리인 글자만 찾아 자르기)
#
#   그 후, 2019에서 뺀 값으로 대체

# %%
def cut_func(x):
    if len(str(x)) == 10:
        return str(x)[:4]

# %%
train['dt_of_athrztn'] = train['dt_of_athrztn'].apply(cut_func)
test['dt_of_athrztn'] = test['dt_of_athrztn'].apply(cut_func)
validation['dt_of_athrztn'] = validation['dt_of_athrztn'].apply(cut_func)

# %%
train['dt_of_athrztn'] = pd.to_numeric(train['dt_of_athrztn'])
test['dt_of_athrztn'] = pd.to_numeric(test['dt_of_athrztn'])
validation['dt_of_athrztn'] = pd.to_numeric(validation['dt_of_athrztn'])

# %%
train['dt_of_athrztn'] = 2019 - train['dt_of_athrztn']
test['dt_of_athrztn'] = 2019 - test['dt_of_athrztn']
validation['dt_of_athrztn'] = 2019 - validation['dt_of_athrztn']

# %% [markdown]
# - 지상층, 지하층, 건물채수 카테고리화

# %%
train_data = [train, test, validation]

# %%
# 지상층 카테고리화

for dataset in train_data:
    dataset.loc[dataset['ttl_grnd_flr'] == 0, 'ttl_grnd_flr'] = 0,
    dataset.loc[(dataset['ttl_grnd_flr'] >= 1) &  (dataset['ttl_grnd_flr'] <= 10), 'ttl_grnd_flr'] = 10, 
    dataset.loc[(dataset['ttl_grnd_flr'] > 10) &  (dataset['ttl_grnd_flr'] <= 20), 'ttl_grnd_flr'] = 20,
    dataset.loc[(dataset['ttl_grnd_flr'] > 20) &  (dataset['ttl_grnd_flr'] <= 30), 'ttl_grnd_flr'] = 30,
    dataset.loc[(dataset['ttl_grnd_flr'] > 30) &  (dataset['ttl_grnd_flr'] <= 40), 'ttl_grnd_flr'] = 40,
    dataset.loc[(dataset['ttl_grnd_flr'] > 40) &  (dataset['ttl_grnd_flr'] <= 55), 'ttl_grnd_flr'] = 55,
    dataset.loc[dataset['ttl_grnd_flr'] > 55, 'ttl_grnd_flr'] = 56

# %%
# 지하층 카테고리화

for dataset in train_data:
    dataset.loc[dataset['ttl_dwn_flr'] == 0, 'ttl_dwn_flr'] = 0,
    dataset.loc[(dataset['ttl_dwn_flr'] >= 1) &  (dataset['ttl_dwn_flr'] <= 4), 'ttl_dwn_flr'] = 4, 
    dataset.loc[(dataset['ttl_dwn_flr'] > 4) &  (dataset['ttl_dwn_flr'] <= 10), 'ttl_dwn_flr'] = 10,
    dataset.loc[(dataset['ttl_dwn_flr'] > 10) &  (dataset['ttl_dwn_flr'] <= 20), 'ttl_dwn_flr'] = 20,
    dataset.loc[dataset['ttl_dwn_flr'] > 20, 'ttl_dwn_flr'] = 21

# %%
# 건물 채수 카테고리화

for dataset in train_data:
    dataset.loc[dataset['bldng_cnt'] == 0, 'bldng_cnt'] = 0,
    dataset.loc[(dataset['bldng_cnt'] >= 1) &  (dataset['bldng_cnt'] <= 5), 'bldng_cnt'] = 5, 
    dataset.loc[(dataset['bldng_cnt'] > 5) &  (dataset['bldng_cnt'] <= 10), 'bldng_cnt'] = 10,
    dataset.loc[(dataset['bldng_cnt'] > 10) &  (dataset['bldng_cnt'] <= 20), 'bldng_cnt'] = 20,
    dataset.loc[(dataset['bldng_cnt'] > 20) &  (dataset['bldng_cnt'] <= 30), 'bldng_cnt'] = 30,
    dataset.loc[dataset['bldng_cnt'] > 30, 'bldng_cnt'] = 31

# %% [markdown]
# ### + nan 인지 아닌지 여부를 나타내는 column 추가 (그냥 해본 것)

# %%
train.isnull().sum()
# Out:
# dt_of_fr                        0
# fr_yn                           0
# bldng_us                    27677
# bldng_archtctr              27665
# bldng_cnt                       0
#                             ...
# us_yn                       49447
# dngrs_thng_yn               49447
# slf_fr_brgd_yn              49447
# blk_dngrs_thng_mnfctr_yn    49447
# cltrl_hrtg_yn               49447
# Length: 180, dtype: int64

# %%
new_train = train.copy()

cols_with_missing = (col for col in new_train.columns 
                                 if new_train[col].isnull().any())
for col in cols_with_missing:
    new_train[col + '_was_missing'] = new_train[col].isnull()

# %%
new_train.head()
# Out:
#            dt_of_fr fr_yn bldng_us bldng_archtctr  bldng_cnt  bldng_ar  \
# 0  2017-10-20 05:54     Y     단독주택           블록구조          5     69.42
# 1  2018-09-30 08:26     N      NaN            NaN          5     46.29
# 2  2016-10-30 14:57     Y     공동주택       철근콘크리트구조          5    583.80
# 3  2016-06-14 05:23     N     단독주택          일반목구조          5     48.92
# 4  2018-04-22 05:38     N      NaN            NaN          5      0.00
#
#     ttl_ar  lnd_ar  dt_of_athrztn  ttl_grnd_flr  ...  \
# 0    69.42     0.0            NaN          10.0  ...
# 1    46.29     0.0            NaN          10.0  ...
# 2  2516.76  1446.0           19.0          10.0  ...
# 3    48.92     0.0            NaN          10.0  ...
# 4     0.00     0.0            NaN           NaN  ...
#
#    bldng_ar_prc_was_missing fr_mn_cnt_was_missing  trgt_crtr_was_missing  \
# 0                      True                 False                   True
# 1                     False                 False                   True
# 2                     False                 False                   True
# 3                     False                 False                   True
# 4                      True                 False                   True
#
#    fr_fghtng_fclt_spcl_css_5_yn_was_missing  \
# 0                                      True
# 1                                      True
# 2                                      True
# 3                                      True
# 4                                      True
#
#    fr_fghtng_fclt_spcl_css_6_yn_was_missing  us_yn_was_missing  \
# 0                                      True               True
# 1                                      True               True
# 2                                      True               True
# 3                                      True               True
# 4                                      True               True
#
#    dngrs_thng_yn_was_missing  slf_fr_brgd_yn_was_missing  \
# 0                       True                        True
# 1                       True                        True
# 2                       True                        True
# 3                       True                        True
# 4                       True                        True
#
#    blk_dngrs_thng_mnfctr_yn_was_missing  cltrl_hrtg_yn_was_missing
# 0                                  True                       True
# 1                                  True                       True
# 2                                  True                       True
# 3                                  True                       True
# 4                                  True                       True
#
# [5 rows x 341 columns]

# %% [markdown]
# ## 3. 최종 pipeline

# %%
building_categorical_feature_1 = ['bldng_us', 'bldng_archtctr', 'bldng_us_clssfctn']
building_categorical_feature_2 = ['ttl_grnd_flr', 'ttl_dwn_flr', 'bldng_cnt']
building_numeric_feature = ['bldng_ar', 'ttl_ar', 'lnd_ar']
building_date = ['dt_of_athrztn']

building_categorical_transformer_1 = Pipeline(steps = [
    ('imp', SimpleImputer(strategy = 'constant', fill_value = 'blank')),
    ('OneHotEncoer', OneHotEncoder(handle_unknown = 'ignore', sparse = False))
])

building_categorical_transformer_2 = Pipeline(steps = [
    ('zero', SimpleImputer(strategy = 'constant', fill_value = 0)),
    ('OneHotEncoer', OneHotEncoder(handle_unknown = 'ignore', sparse = False))
])

building_numeric_transformer = Pipeline(steps = [
    ('scaling', StandardScaler()),
    ('pca', PCA()),
])


building_date_transformer = Pipeline([
    ('imp', SimpleImputer(strategy = 'constant', fill_value = 0))
])


processor = ColumnTransformer(
    transformers = [
    ('cat1', building_categorical_transformer_1, building_categorical_feature_1),
    ('cat2', building_categorical_transformer_2, building_categorical_feature_2),
    ('num', building_numeric_transformer, building_numeric_feature),
    ('date', building_date_transformer, building_date)
])


pipe = Pipeline(steps = [('processor', processor)
])

# %%
pipe.fit_transform(train)
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -8.80615594e-03, -3.14938998e-02,  0.00000000e+00],
#        [ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -8.54311329e-03, -3.32894353e-02,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00, ...,
#          6.89478937e-03,  4.49195465e-03,  1.90000000e+01],
#        ...,
#        [ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -3.66272430e-02,  1.50212322e-01,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -1.20899012e-02, -1.47619928e-02,  1.40000000e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -1.00454212e-02, -2.39094719e-02,  1.70000000e+01]])

# %%
pipe.fit_transform(test)
# Out:
# array([[ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -3.55668817e-02, -3.02043555e-02,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00, ...,
#         -2.30308171e-02,  2.97517406e-02,  1.80000000e+01],
#        [ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          2.02863515e-02,  3.01371394e-01,  0.00000000e+00],
#        ...,
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -3.49151746e-02, -2.13867078e-02,  7.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -3.14238219e-02, -1.37903765e-02,  1.00000000e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -2.53647625e-02,  7.63189983e-02,  2.10000000e+01]])

# %%
pipe.fit_transform(validation)
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -2.59325730e-02, -2.26087926e-02,  3.30000000e+01],
#        [ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -2.65925114e-02, -2.09072409e-02,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -2.71128275e-02, -2.12964202e-02,  1.30000000e+01],
#        ...,
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -2.58089422e-02, -2.14643832e-02,  1.90000000e+01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -2.70887524e-02, -2.04769465e-02,  2.60000000e+01],
#        [ 0.00000000e+00,  1.00000000e+00,  0.00000000e+00, ...,
#         -2.66056182e-02, -1.08727928e-02,  1.60000000e+01]])

# %% [markdown]
# ## 추가: imputation하는 다른 방법들
#
# 참고: https://data-newbie.tistory.com/257

# %% [markdown]
# 제가 맡은 변수에서는 nan 개수가 유의미하게 줄어들지 않았습니다. 효과는 잘 모르겠습니다...

# %% [markdown]
# ### 1) using datawig
#
# https://pypi.org/project/datawig/

# %%
from datawig import SimpleImputer
from datawig.utils import random_split
from sklearn.metrics import f1_score, classification_report
df_train, df_test = random_split(train, split_ratios=[0.8, 0.2])
# Initialize a SimpleImputer model
imputer = SimpleImputer(
input_columns=['bldng_cnt', 'bldng_ar','ttl_ar', 'lnd_ar', 'ground_floor', 'down_floor'],  # columns containing information about 
output_column='bldng_us',  # the column we'd like to impute values for
output_path='imputer_model'  # stores model data and metrics
)

# Fit an imputer model on the train data
imputer.fit(train_df= df_train, num_epochs=10)

# Impute missing values and return original dataframe with predictions
predictions = imputer.predict(df_test)
# Out:
# 2019-11-30 11:49:28,103 [INFO]  CategoricalEncoder for column bldng_us                                found only 95 occurrences of value 업무시설
# 2019-11-30 11:49:28,104 [INFO]  CategoricalEncoder for column bldng_us                                found only 90 occurrences of value 위험물저장및처리시설
# 2019-11-30 11:49:28,106 [INFO]  CategoricalEncoder for column bldng_us                                found only 83 occurrences of value 자동차관련시설
# 2019-11-30 11:49:28,107 [INFO]  CategoricalEncoder for column bldng_us                                found only 42 occurrences of value 판매시설
# 2019-11-30 11:49:28,108 [INFO]  CategoricalEncoder for column bldng_us                                found only 38 occurrences of value 분뇨.쓰레기처리시설
# 2019-11-30 11:49:28,109 [INFO]  CategoricalEncoder for column bldng_us                                found only 34 occurrences of value 운동시설
# 2019-11-30 11:49:28,110 [INFO]  CategoricalEncoder for column bldng_us                                found only 27 occurrences of value 위락시설
# 2019-11-30 11:49:28,111 [INFO]  CategoricalEncoder for column bldng_us                                found only 27 occurrences of value 관광휴게시설
# 2019-11-30 11:49:28,112 [INFO]  CategoricalEncoder for column bldng_us                                found only 25 occurrences of value 문화및집회시설
# 2019-11-30 11:49:28,113 [INFO]  CategoricalEncoder for column bldng_us                                found only 24 occurrences of value 근린생활시설
# 2019-11-30 11:49:28,115 [INFO]  CategoricalEncoder for column bldng_us                                found only 19 occurrences of value 의료시설
# 2019-11-30 11:49:28,116 [INFO]  CategoricalEncoder for column bldng_us                                found only 13 occurrences of value 교육연구및복지시설
# 2019-11-30 11:49:28,118 [INFO]  CategoricalEncoder for column bldng_us                                found only 11 occurrences of value 수련시설
# 2019-11-30 11:49:28,119 [INFO]  CategoricalEncoder for column bldng_us                                found only 9 occurrences of value 발전시설
# 2019-11-30 11:49:28,121 [INFO]  CategoricalEncoder for column bldng_us                                found only 7 occurrences of value 운수시설
# 2019-11-30 11:49:28,123 [INFO]  CategoricalEncoder for column bldng_us                                found only 7 occurrences of value 방송통신시설
# 2019-11-30 11:49:28,125 [INFO]  CategoricalEncoder for column bldng_us                                found only 5 occurrences of value 묘지관련시설
# 2019-11-30 11:49:28,126 [INFO]  CategoricalEncoder for column bldng_us                                found only 4 occurrences of value 교정및군사시설
# 2019-11-30 11:49:28,127 [INFO]  CategoricalEncoder for column bldng_us                                found only 2 occurrences of value 장례식장
# 2019-11-30 11:49:28,129 [INFO]  CategoricalEncoder for column bldng_us                                found only 1 occurrences of value 판매및영업시설
# 2019-11-30 11:49:28,130 [INFO]  CategoricalEncoder for column bldng_us                                found only 1 occurrences of value 파출소
# 2019-11-30 11:49:28,131 [INFO]  CategoricalEncoder for column bldng_us                                found only 1 occurrences of value 시장
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\frame.py:3509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# 2019-11-30 11:49:30,252 [WARNING]  Test set does not contain any ocurrences of values [발전시설, 수련시설, 판매및영업시설, 파출소, 시장] in column [bldng_us], consider using a more representative test set.
# 2019-11-30 11:49:30,259 [INFO]
# ========== start: fit model
# 2019-11-30 11:49:30,260 [WARNING]  Already bound, ignoring bind()
# 2019-11-30 11:49:31,110 [INFO]  Epoch[0] Batch [0-708]	Speed: 13431.39 samples/sec	cross-entropy=1.321896	bldng_us-accuracy=0.657793
# 2019-11-30 11:49:31,988 [INFO]  Epoch[0] Train-cross-entropy=1.147894
# 2019-11-30 11:49:31,990 [INFO]  Epoch[0] Train-bldng_us-accuracy=0.683428
# 2019-11-30 11:49:31,992 [INFO]  Epoch[0] Time cost=1.729
# 2019-11-30 11:49:32,000 [INFO]  Saved checkpoint to "imputer_model\model-0000.params"
# 2019-11-30 11:49:32,137 [INFO]  Epoch[0] Validation-cross-entropy=1.158826
# 2019-11-30 11:49:32,139 [INFO]  Epoch[0] Validation-bldng_us-accuracy=0.675613
# 2019-11-30 11:49:33,032 [INFO]  Epoch[1] Batch [0-708]	Speed: 12741.40 samples/sec	cross-entropy=1.135588	bldng_us-accuracy=0.680448
# 2019-11-30 11:49:33,979 [INFO]  Epoch[1] Train-cross-entropy=1.080238
# 2019-11-30 11:49:33,981 [INFO]  Epoch[1] Train-bldng_us-accuracy=0.692989
# 2019-11-30 11:49:33,982 [INFO]  Epoch[1] Time cost=1.842
# 2019-11-30 11:49:33,989 [INFO]  Saved checkpoint to "imputer_model\model-0001.params"
# 2019-11-30 11:49:34,127 [INFO]  Epoch[1] Validation-cross-entropy=1.115779
# 2019-11-30 11:49:34,129 [INFO]  Epoch[1] Validation-bldng_us-accuracy=0.684816
# 2019-11-30 11:49:34,947 [INFO]  Epoch[2] Batch [0-708]	Speed: 13936.58 samples/sec	cross-entropy=1.099293	bldng_us-accuracy=0.686354
# 2019-11-30 11:49:35,816 [INFO]  Epoch[2] Train-cross-entropy=1.061289
# 2019-11-30 11:49:35,817 [INFO]  Epoch[2] Train-bldng_us-accuracy=0.696087
# 2019-11-30 11:49:35,818 [INFO]  Epoch[2] Time cost=1.687
# 2019-11-30 11:49:35,825 [INFO]  Saved checkpoint to "imputer_model\model-0002.params"
# 2019-11-30 11:49:35,976 [INFO]  Epoch[2] Validation-cross-entropy=1.110447
# 2019-11-30 11:49:35,978 [INFO]  Epoch[2] Validation-bldng_us-accuracy=0.685583
# 2019-11-30 11:49:36,948 [INFO]  Epoch[3] Batch [0-708]	Speed: 11709.38 samples/sec	cross-entropy=1.087673	bldng_us-accuracy=0.688293
# 2019-11-30 11:49:37,739 [INFO]  Epoch[3] Train-cross-entropy=1.054022
# 2019-11-30 11:49:37,741 [INFO]  Epoch[3] Train-bldng_us-accuracy=0.698389
# 2019-11-30 11:49:37,742 [INFO]  Epoch[3] Time cost=1.764
# 2019-11-30 11:49:37,751 [INFO]  Saved checkpoint to "imputer_model\model-0003.params"
# 2019-11-30 11:49:37,898 [INFO]  Epoch[3] Validation-cross-entropy=1.104644
# 2019-11-30 11:49:37,900 [INFO]  Epoch[3] Validation-bldng_us-accuracy=0.692868
# 2019-11-30 11:49:38,887 [INFO]  Epoch[4] Batch [0-708]	Speed: 11519.58 samples/sec	cross-entropy=1.080604	bldng_us-accuracy=0.689880
# 2019-11-30 11:49:39,757 [INFO]  Epoch[4] Train-cross-entropy=1.050274
# 2019-11-30 11:49:39,759 [INFO]  Epoch[4] Train-bldng_us-accuracy=0.699363
# 2019-11-30 11:49:39,761 [INFO]  Epoch[4] Time cost=1.861
# 2019-11-30 11:49:39,768 [INFO]  Saved checkpoint to "imputer_model\model-0004.params"
# 2019-11-30 11:49:39,908 [INFO]  Epoch[4] Validation-cross-entropy=1.102444
# 2019-11-30 11:49:39,910 [INFO]  Epoch[4] Validation-bldng_us-accuracy=0.688267
# 2019-11-30 11:49:40,770 [INFO]  Epoch[5] Batch [0-708]	Speed: 13235.79 samples/sec	cross-entropy=1.073413	bldng_us-accuracy=0.690497
# 2019-11-30 11:49:41,668 [INFO]  Epoch[5] Train-cross-entropy=1.045894
# 2019-11-30 11:49:41,670 [INFO]  Epoch[5] Train-bldng_us-accuracy=0.700071
# 2019-11-30 11:49:41,671 [INFO]  Epoch[5] Time cost=1.760
# 2019-11-30 11:49:41,678 [INFO]  Saved checkpoint to "imputer_model\model-0005.params"
# 2019-11-30 11:49:41,816 [INFO]  Epoch[5] Validation-cross-entropy=1.101268
# 2019-11-30 11:49:41,818 [INFO]  Epoch[5] Validation-bldng_us-accuracy=0.689801
# 2019-11-30 11:49:42,684 [INFO]  Epoch[6] Batch [0-708]	Speed: 13135.83 samples/sec	cross-entropy=1.073586	bldng_us-accuracy=0.689792
# 2019-11-30 11:49:43,644 [INFO]  Epoch[6] Train-cross-entropy=1.042346
# 2019-11-30 11:49:43,645 [INFO]  Epoch[6] Train-bldng_us-accuracy=0.700336
# 2019-11-30 11:49:43,646 [INFO]  Epoch[6] Time cost=1.827
# 2019-11-30 11:49:43,653 [INFO]  Saved checkpoint to "imputer_model\model-0006.params"
# 2019-11-30 11:49:43,792 [INFO]  Epoch[6] Validation-cross-entropy=1.098925
# 2019-11-30 11:49:43,793 [INFO]  Epoch[6] Validation-bldng_us-accuracy=0.690951
# 2019-11-30 11:49:44,626 [INFO]  Epoch[7] Batch [0-708]	Speed: 13676.02 samples/sec	cross-entropy=1.064987	bldng_us-accuracy=0.689968
# 2019-11-30 11:49:45,442 [INFO]  Epoch[7] Train-cross-entropy=1.042284
# 2019-11-30 11:49:45,444 [INFO]  Epoch[7] Train-bldng_us-accuracy=0.700159
# 2019-11-30 11:49:45,445 [INFO]  Epoch[7] Time cost=1.649
# 2019-11-30 11:49:45,452 [INFO]  Saved checkpoint to "imputer_model\model-0007.params"
# 2019-11-30 11:49:45,599 [INFO]  Epoch[7] Validation-cross-entropy=1.097753
# 2019-11-30 11:49:45,600 [INFO]  Epoch[7] Validation-bldng_us-accuracy=0.690951
# 2019-11-30 11:49:46,525 [INFO]  Epoch[8] Batch [0-708]	Speed: 12292.54 samples/sec	cross-entropy=1.058386	bldng_us-accuracy=0.691379
# 2019-11-30 11:49:47,356 [INFO]  Epoch[8] Train-cross-entropy=1.037747
# 2019-11-30 11:49:47,358 [INFO]  Epoch[8] Train-bldng_us-accuracy=0.700779
# 2019-11-30 11:49:47,360 [INFO]  Epoch[8] Time cost=1.759
# 2019-11-30 11:49:47,368 [INFO]  Saved checkpoint to "imputer_model\model-0008.params"
# 2019-11-30 11:49:47,502 [INFO]  Epoch[8] Validation-cross-entropy=1.097040
# 2019-11-30 11:49:47,503 [INFO]  Epoch[8] Validation-bldng_us-accuracy=0.690951
# 2019-11-30 11:49:48,359 [INFO]  Epoch[9] Batch [0-708]	Speed: 13292.21 samples/sec	cross-entropy=1.056362	bldng_us-accuracy=0.690762
# 2019-11-30 11:49:49,251 [INFO]  Epoch[9] Train-cross-entropy=1.038195
# 2019-11-30 11:49:49,253 [INFO]  Epoch[9] Train-bldng_us-accuracy=0.701576
# 2019-11-30 11:49:49,254 [INFO]  Epoch[9] Time cost=1.749
# 2019-11-30 11:49:49,263 [INFO]  Saved checkpoint to "imputer_model\model-0009.params"
# 2019-11-30 11:49:49,425 [INFO]  Epoch[9] Validation-cross-entropy=1.097659
# 2019-11-30 11:49:49,426 [INFO]  Epoch[9] Validation-bldng_us-accuracy=0.689417
# 2019-11-30 11:49:49,428 [INFO]
# ========== done (19.169965505599976 s) fit model
# C:\Users\user\Anaconda3\lib\site-packages\datawig\calibration.py:92: RuntimeWarning: divide by zero encountered in log
#   return np.log(probas)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\user\Anaconda3\lib\site-packages\datawig\calibration.py:92: RuntimeWarning: divide by zero encountered in log
#   return np.log(probas)
# C:\Users\user\Anaconda3\lib\site-packages\datawig\imputer.py:822: FutureWarning: The 'contains' method is deprecated and will be removed in a future version. Use 'key in index' instead of 'index.contains(key)'
#   if data_frame.columns.contains(imputation_col):
# C:\Users\user\Anaconda3\lib\site-packages\datawig\imputer.py:829: FutureWarning: The 'contains' method is deprecated and will be removed in a future version. Use 'key in index' instead of 'index.contains(key)'
#   if data_frame.columns.contains(imputation_proba_col):

# %%
imputer.fit(train)
# Out:
# 2019-11-30 11:49:58,281 [WARNING]  Test set does not contain any ocurrences of values [판매및영업시설, 수련시설, 관광휴게시설, 파출소, 방송통신시설, 시장, 장례식장] in column [bldng_us], consider using a more representative test set.
# 2019-11-30 11:49:58,282 [INFO]
# ========== start: fit model
# 2019-11-30 11:49:58,283 [WARNING]  Already bound, ignoring bind()
# C:\Users\user\Anaconda3\lib\site-packages\mxnet\module\base_module.py:502: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# 2019-11-30 11:49:58,285 [WARNING]  optimizer already initialized, ignoring...
# 2019-11-30 11:49:59,824 [INFO]  Epoch[0] Batch [0-886]	Speed: 9235.20 samples/sec	cross-entropy=1.056065	bldng_us-accuracy=0.693842
# 2019-11-30 11:50:01,128 [INFO]  Epoch[0] Train-cross-entropy=1.044258
# 2019-11-30 11:50:01,130 [INFO]  Epoch[0] Train-bldng_us-accuracy=0.698446
# 2019-11-30 11:50:01,131 [INFO]  Epoch[0] Time cost=2.845
# 2019-11-30 11:50:01,140 [INFO]  Saved checkpoint to "imputer_model\model-0000.params"
# 2019-11-30 11:50:01,346 [INFO]  Epoch[0] Validation-cross-entropy=1.089418
# 2019-11-30 11:50:01,348 [INFO]  Epoch[0] Validation-bldng_us-accuracy=0.675565
# 2019-11-30 11:50:02,593 [INFO]  Epoch[1] Batch [0-886]	Speed: 11425.64 samples/sec	cross-entropy=1.048191	bldng_us-accuracy=0.694687
# 2019-11-30 11:50:03,757 [INFO]  Epoch[1] Train-cross-entropy=1.039151
# 2019-11-30 11:50:03,758 [INFO]  Epoch[1] Train-bldng_us-accuracy=0.699294
# 2019-11-30 11:50:03,759 [INFO]  Epoch[1] Time cost=2.410
# 2019-11-30 11:50:03,766 [INFO]  Saved checkpoint to "imputer_model\model-0001.params"
# 2019-11-30 11:50:03,934 [INFO]  Epoch[1] Validation-cross-entropy=1.090545
# 2019-11-30 11:50:03,936 [INFO]  Epoch[1] Validation-bldng_us-accuracy=0.674623
# 2019-11-30 11:50:05,069 [INFO]  Epoch[2] Batch [0-886]	Speed: 12553.43 samples/sec	cross-entropy=1.051527	bldng_us-accuracy=0.693137
# 2019-11-30 11:50:06,333 [INFO]  Epoch[2] Train-cross-entropy=1.036213
# 2019-11-30 11:50:06,334 [INFO]  Epoch[2] Train-bldng_us-accuracy=0.700071
# 2019-11-30 11:50:06,336 [INFO]  Epoch[2] Time cost=2.399
# 2019-11-30 11:50:06,344 [INFO]  Saved checkpoint to "imputer_model\model-0002.params"
# 2019-11-30 11:50:06,520 [INFO]  Epoch[2] Validation-cross-entropy=1.083996
# 2019-11-30 11:50:06,522 [INFO]  Epoch[2] Validation-bldng_us-accuracy=0.676822
# 2019-11-30 11:50:07,748 [INFO]  Epoch[3] Batch [0-886]	Speed: 11594.38 samples/sec	cross-entropy=1.044083	bldng_us-accuracy=0.694969
# 2019-11-30 11:50:09,152 [INFO]  Epoch[3] Train-cross-entropy=1.033689
# 2019-11-30 11:50:09,154 [INFO]  Epoch[3] Train-bldng_us-accuracy=0.700353
# 2019-11-30 11:50:09,156 [INFO]  Epoch[3] Time cost=2.633
# 2019-11-30 11:50:09,164 [INFO]  Saved checkpoint to "imputer_model\model-0003.params"
# 2019-11-30 11:50:09,344 [INFO]  Epoch[3] Validation-cross-entropy=1.081880
# 2019-11-30 11:50:09,346 [INFO]  Epoch[3] Validation-bldng_us-accuracy=0.675565
# 2019-11-30 11:50:10,574 [INFO]  Epoch[4] Batch [0-886]	Speed: 11576.16 samples/sec	cross-entropy=1.041385	bldng_us-accuracy=0.694758
# 2019-11-30 11:50:11,762 [INFO]  Epoch[4] Train-cross-entropy=1.033007
# 2019-11-30 11:50:11,763 [INFO]  Epoch[4] Train-bldng_us-accuracy=0.700918
# 2019-11-30 11:50:11,764 [INFO]  Epoch[4] Time cost=2.416
# 2019-11-30 11:50:11,772 [INFO]  Saved checkpoint to "imputer_model\model-0004.params"
# 2019-11-30 11:50:11,960 [INFO]  Epoch[4] Validation-cross-entropy=1.080053
# 2019-11-30 11:50:11,963 [INFO]  Epoch[4] Validation-bldng_us-accuracy=0.677450
# 2019-11-30 11:50:13,177 [INFO]  Epoch[5] Batch [0-886]	Speed: 11720.03 samples/sec	cross-entropy=1.039047	bldng_us-accuracy=0.695462
# 2019-11-30 11:50:14,388 [INFO]  Epoch[5] Train-cross-entropy=1.026716
# 2019-11-30 11:50:14,390 [INFO]  Epoch[5] Train-bldng_us-accuracy=0.700424
# 2019-11-30 11:50:14,392 [INFO]  Epoch[5] Time cost=2.427
# 2019-11-30 11:50:14,399 [INFO]  Saved checkpoint to "imputer_model\model-0005.params"
# 2019-11-30 11:50:14,579 [INFO]  Epoch[5] Validation-cross-entropy=1.079580
# 2019-11-30 11:50:14,581 [INFO]  Epoch[5] Validation-bldng_us-accuracy=0.676193
# 2019-11-30 11:50:15,785 [INFO]  Epoch[6] Batch [0-886]	Speed: 11805.29 samples/sec	cross-entropy=1.037323	bldng_us-accuracy=0.695533
# 2019-11-30 11:50:16,846 [INFO]  Epoch[6] Train-cross-entropy=1.029299
# 2019-11-30 11:50:16,847 [INFO]  Epoch[6] Train-bldng_us-accuracy=0.701695
# 2019-11-30 11:50:16,849 [INFO]  Epoch[6] Time cost=2.266
# 2019-11-30 11:50:16,855 [INFO]  Saved checkpoint to "imputer_model\model-0006.params"
# 2019-11-30 11:50:17,032 [INFO]  Epoch[6] Validation-cross-entropy=1.079460
# 2019-11-30 11:50:17,034 [INFO]  Epoch[6] Validation-bldng_us-accuracy=0.678392
# 2019-11-30 11:50:18,420 [INFO]  Epoch[7] Batch [0-886]	Speed: 10250.16 samples/sec	cross-entropy=1.035698	bldng_us-accuracy=0.695392
# 2019-11-30 11:50:19,532 [INFO]  Epoch[7] Train-cross-entropy=1.023691
# 2019-11-30 11:50:19,533 [INFO]  Epoch[7] Train-bldng_us-accuracy=0.702331
# 2019-11-30 11:50:19,534 [INFO]  Epoch[7] Time cost=2.499
# 2019-11-30 11:50:19,543 [INFO]  Saved checkpoint to "imputer_model\model-0007.params"
# 2019-11-30 11:50:19,724 [INFO]  Epoch[7] Validation-cross-entropy=1.077499
# 2019-11-30 11:50:19,725 [INFO]  Epoch[7] Validation-bldng_us-accuracy=0.676508
# 2019-11-30 11:50:20,926 [INFO]  Epoch[8] Batch [0-886]	Speed: 11844.09 samples/sec	cross-entropy=1.031829	bldng_us-accuracy=0.697294
# 2019-11-30 11:50:22,096 [INFO]  Epoch[8] Train-cross-entropy=1.019443
# 2019-11-30 11:50:22,098 [INFO]  Epoch[8] Train-bldng_us-accuracy=0.702542
# 2019-11-30 11:50:22,099 [INFO]  Epoch[8] Time cost=2.373
# 2019-11-30 11:50:22,106 [INFO]  Saved checkpoint to "imputer_model\model-0008.params"
# 2019-11-30 11:50:22,275 [INFO]  Epoch[8] Validation-cross-entropy=1.078324
# 2019-11-30 11:50:22,276 [INFO]  Epoch[8] Validation-bldng_us-accuracy=0.675565
# 2019-11-30 11:50:23,350 [INFO]  Epoch[9] Batch [0-886]	Speed: 13238.61 samples/sec	cross-entropy=1.030403	bldng_us-accuracy=0.695392
# 2019-11-30 11:50:24,433 [INFO]  Epoch[9] Train-cross-entropy=1.022637
# 2019-11-30 11:50:24,436 [INFO]  Epoch[9] Train-bldng_us-accuracy=0.701766
# 2019-11-30 11:50:24,438 [INFO]  Epoch[9] Time cost=2.161
# 2019-11-30 11:50:24,446 [INFO]  Saved checkpoint to "imputer_model\model-0009.params"
# 2019-11-30 11:50:24,611 [INFO]  Epoch[9] Validation-cross-entropy=1.077131
# 2019-11-30 11:50:24,613 [INFO]  Epoch[9] Validation-bldng_us-accuracy=0.676822
# 2019-11-30 11:50:25,729 [INFO]  Epoch[10] Batch [0-886]	Speed: 12743.48 samples/sec	cross-entropy=1.028589	bldng_us-accuracy=0.696308
# 2019-11-30 11:50:26,839 [INFO]  Epoch[10] Train-cross-entropy=1.015674
# 2019-11-30 11:50:26,840 [INFO]  Epoch[10] Train-bldng_us-accuracy=0.703178
# 2019-11-30 11:50:26,841 [INFO]  Epoch[10] Time cost=2.226
# 2019-11-30 11:50:26,850 [INFO]  Saved checkpoint to "imputer_model\model-0010.params"
# 2019-11-30 11:50:27,010 [INFO]  Epoch[10] Validation-cross-entropy=1.074436
# 2019-11-30 11:50:27,012 [INFO]  Epoch[10] Validation-bldng_us-accuracy=0.675565
# 2019-11-30 11:50:28,093 [INFO]  Epoch[11] Batch [0-886]	Speed: 13142.58 samples/sec	cross-entropy=1.026650	bldng_us-accuracy=0.696026
# 2019-11-30 11:50:29,440 [INFO]  Epoch[11] Train-cross-entropy=1.015048
# 2019-11-30 11:50:29,441 [INFO]  Epoch[11] Train-bldng_us-accuracy=0.702825
# 2019-11-30 11:50:29,442 [INFO]  Epoch[11] Time cost=2.429
# 2019-11-30 11:50:29,450 [INFO]  Saved checkpoint to "imputer_model\model-0011.params"
# 2019-11-30 11:50:29,609 [INFO]  Epoch[11] Validation-cross-entropy=1.076466
# 2019-11-30 11:50:29,611 [INFO]  Epoch[11] Validation-bldng_us-accuracy=0.676193
# 2019-11-30 11:50:30,737 [INFO]  Epoch[12] Batch [0-886]	Speed: 12624.12 samples/sec	cross-entropy=1.025184	bldng_us-accuracy=0.697012
# 2019-11-30 11:50:31,931 [INFO]  Epoch[12] Train-cross-entropy=1.018743
# 2019-11-30 11:50:31,933 [INFO]  Epoch[12] Train-bldng_us-accuracy=0.703814
# 2019-11-30 11:50:31,934 [INFO]  Epoch[12] Time cost=2.321
# 2019-11-30 11:50:31,944 [INFO]  Saved checkpoint to "imputer_model\model-0012.params"
# 2019-11-30 11:50:32,104 [INFO]  Epoch[12] Validation-cross-entropy=1.072830
# 2019-11-30 11:50:32,105 [INFO]  Epoch[12] Validation-bldng_us-accuracy=0.675565
# 2019-11-30 11:50:33,235 [INFO]  Epoch[13] Batch [0-886]	Speed: 12592.07 samples/sec	cross-entropy=1.025439	bldng_us-accuracy=0.696096
# 2019-11-30 11:50:34,276 [INFO]  Epoch[13] Train-cross-entropy=1.011944
# 2019-11-30 11:50:34,278 [INFO]  Epoch[13] Train-bldng_us-accuracy=0.703884
# 2019-11-30 11:50:34,279 [INFO]  Epoch[13] Time cost=2.172
# 2019-11-30 11:50:34,287 [INFO]  Saved checkpoint to "imputer_model\model-0013.params"
# 2019-11-30 11:50:34,460 [INFO]  Epoch[13] Validation-cross-entropy=1.074693
# 2019-11-30 11:50:34,461 [INFO]  Epoch[13] Validation-bldng_us-accuracy=0.676193
# 2019-11-30 11:50:35,532 [INFO]  Epoch[14] Batch [0-886]	Speed: 13281.03 samples/sec	cross-entropy=1.024372	bldng_us-accuracy=0.696167
# 2019-11-30 11:50:36,627 [INFO]  Epoch[14] Train-cross-entropy=1.009973
# 2019-11-30 11:50:36,628 [INFO]  Epoch[14] Train-bldng_us-accuracy=0.703531
# 2019-11-30 11:50:36,629 [INFO]  Epoch[14] Time cost=2.167
# 2019-11-30 11:50:36,637 [INFO]  Saved checkpoint to "imputer_model\model-0014.params"
# 2019-11-30 11:50:36,794 [INFO]  Epoch[14] Validation-cross-entropy=1.072872
# 2019-11-30 11:50:36,796 [INFO]  Epoch[14] Validation-bldng_us-accuracy=0.676508
# 2019-11-30 11:50:37,878 [INFO]  Epoch[15] Batch [0-886]	Speed: 13140.55 samples/sec	cross-entropy=1.021812	bldng_us-accuracy=0.696096
# 2019-11-30 11:50:38,955 [INFO]  Epoch[15] Train-cross-entropy=1.009720
# 2019-11-30 11:50:38,957 [INFO]  Epoch[15] Train-bldng_us-accuracy=0.704237
# 2019-11-30 11:50:38,958 [INFO]  Epoch[15] Time cost=2.161
# 2019-11-30 11:50:38,968 [INFO]  Saved checkpoint to "imputer_model\model-0015.params"
# 2019-11-30 11:50:39,131 [INFO]  Epoch[15] Validation-cross-entropy=1.076697
# 2019-11-30 11:50:39,132 [INFO]  Epoch[15] Validation-bldng_us-accuracy=0.675251
# 2019-11-30 11:50:40,244 [INFO]  Epoch[16] Batch [0-886]	Speed: 12810.78 samples/sec	cross-entropy=1.019502	bldng_us-accuracy=0.697506
# 2019-11-30 11:50:41,287 [INFO]  Epoch[16] Train-cross-entropy=1.007290
# 2019-11-30 11:50:41,289 [INFO]  Epoch[16] Train-bldng_us-accuracy=0.704167
# 2019-11-30 11:50:41,291 [INFO]  Epoch[16] Time cost=2.157
# 2019-11-30 11:50:41,300 [INFO]  Saved checkpoint to "imputer_model\model-0016.params"
# 2019-11-30 11:50:41,473 [INFO]  Epoch[16] Validation-cross-entropy=1.072016
# 2019-11-30 11:50:41,475 [INFO]  Epoch[16] Validation-bldng_us-accuracy=0.674937
# 2019-11-30 11:50:42,582 [INFO]  Epoch[17] Batch [0-886]	Speed: 12847.04 samples/sec	cross-entropy=1.020633	bldng_us-accuracy=0.697224
# 2019-11-30 11:50:43,677 [INFO]  Epoch[17] Train-cross-entropy=1.006469
# 2019-11-30 11:50:43,679 [INFO]  Epoch[17] Train-bldng_us-accuracy=0.704379
# 2019-11-30 11:50:43,681 [INFO]  Epoch[17] Time cost=2.206
# 2019-11-30 11:50:43,689 [INFO]  Saved checkpoint to "imputer_model\model-0017.params"
# 2019-11-30 11:50:43,857 [INFO]  Epoch[17] Validation-cross-entropy=1.072713
# 2019-11-30 11:50:43,859 [INFO]  Epoch[17] Validation-bldng_us-accuracy=0.674623
# 2019-11-30 11:50:45,007 [INFO]  Epoch[18] Batch [0-886]	Speed: 12381.43 samples/sec	cross-entropy=1.023458	bldng_us-accuracy=0.696449
# 2019-11-30 11:50:46,066 [INFO]  Epoch[18] Train-cross-entropy=1.005479
# 2019-11-30 11:50:46,068 [INFO]  Epoch[18] Train-bldng_us-accuracy=0.705508
# 2019-11-30 11:50:46,069 [INFO]  Epoch[18] Time cost=2.209
# 2019-11-30 11:50:46,077 [INFO]  Saved checkpoint to "imputer_model\model-0018.params"
# 2019-11-30 11:50:46,230 [INFO]  Epoch[18] Validation-cross-entropy=1.072383
# 2019-11-30 11:50:46,232 [INFO]  Epoch[18] Validation-bldng_us-accuracy=0.675565
# 2019-11-30 11:50:47,349 [INFO]  Epoch[19] Batch [0-886]	Speed: 12729.95 samples/sec	cross-entropy=1.014113	bldng_us-accuracy=0.697787
# 2019-11-30 11:50:48,495 [INFO]  Epoch[19] Train-cross-entropy=1.005190
# 2019-11-30 11:50:48,496 [INFO]  Epoch[19] Train-bldng_us-accuracy=0.703955
# 2019-11-30 11:50:48,497 [INFO]  Epoch[19] Time cost=2.265
# 2019-11-30 11:50:48,504 [INFO]  Saved checkpoint to "imputer_model\model-0019.params"
# 2019-11-30 11:50:48,664 [INFO]  Epoch[19] Validation-cross-entropy=1.072545
# 2019-11-30 11:50:48,666 [INFO]  Epoch[19] Validation-bldng_us-accuracy=0.674309
# 2019-11-30 11:50:49,700 [INFO]  Epoch[20] Batch [0-886]	Speed: 13756.27 samples/sec	cross-entropy=1.016065	bldng_us-accuracy=0.697999
# 2019-11-30 11:50:50,727 [INFO]  Epoch[20] Train-cross-entropy=1.002910
# 2019-11-30 11:50:50,729 [INFO]  Epoch[20] Train-bldng_us-accuracy=0.705862
# 2019-11-30 11:50:50,730 [INFO]  Epoch[20] Time cost=2.063
# 2019-11-30 11:50:50,737 [INFO]  Saved checkpoint to "imputer_model\model-0020.params"
# 2019-11-30 11:50:50,890 [INFO]  Epoch[20] Validation-cross-entropy=1.072038
# 2019-11-30 11:50:50,891 [INFO]  Epoch[20] Validation-bldng_us-accuracy=0.673995
# 2019-11-30 11:50:52,083 [INFO]  Epoch[21] Batch [0-886]	Speed: 11923.75 samples/sec	cross-entropy=1.013406	bldng_us-accuracy=0.698140
# 2019-11-30 11:50:53,160 [INFO]  Epoch[21] Train-cross-entropy=1.010887
# 2019-11-30 11:50:53,161 [INFO]  Epoch[21] Train-bldng_us-accuracy=0.705014
# 2019-11-30 11:50:53,162 [INFO]  Epoch[21] Time cost=2.269
# 2019-11-30 11:50:53,169 [INFO]  Saved checkpoint to "imputer_model\model-0021.params"
# 2019-11-30 11:50:53,320 [INFO]  Epoch[21] Validation-cross-entropy=1.071249
# 2019-11-30 11:50:53,322 [INFO]  Epoch[21] Validation-bldng_us-accuracy=0.675565
# 2019-11-30 11:50:54,397 [INFO]  Epoch[22] Batch [0-886]	Speed: 13223.17 samples/sec	cross-entropy=1.014044	bldng_us-accuracy=0.698633
# 2019-11-30 11:50:55,528 [INFO]  Epoch[22] Train-cross-entropy=1.001258
# 2019-11-30 11:50:55,530 [INFO]  Epoch[22] Train-bldng_us-accuracy=0.704590
# 2019-11-30 11:50:55,532 [INFO]  Epoch[22] Time cost=2.210
# 2019-11-30 11:50:55,538 [INFO]  Saved checkpoint to "imputer_model\model-0022.params"
# 2019-11-30 11:50:55,687 [INFO]  Epoch[22] Validation-cross-entropy=1.069759
# 2019-11-30 11:50:55,689 [INFO]  Epoch[22] Validation-bldng_us-accuracy=0.674309
# 2019-11-30 11:50:56,730 [INFO]  Epoch[23] Batch [0-886]	Speed: 13651.46 samples/sec	cross-entropy=1.011540	bldng_us-accuracy=0.697294
# 2019-11-30 11:50:57,812 [INFO]  Epoch[23] Train-cross-entropy=1.001408
# 2019-11-30 11:50:57,814 [INFO]  Epoch[23] Train-bldng_us-accuracy=0.705226
# 2019-11-30 11:50:57,814 [INFO]  Epoch[23] Time cost=2.124
# 2019-11-30 11:50:57,822 [INFO]  Saved checkpoint to "imputer_model\model-0023.params"
# 2019-11-30 11:50:57,974 [INFO]  Epoch[23] Validation-cross-entropy=1.073816
# 2019-11-30 11:50:57,976 [INFO]  Epoch[23] Validation-bldng_us-accuracy=0.673681
# 2019-11-30 11:50:59,039 [INFO]  Epoch[24] Batch [0-886]	Speed: 13381.36 samples/sec	cross-entropy=1.013051	bldng_us-accuracy=0.698985
# 2019-11-30 11:50:59,994 [INFO]  Epoch[24] Train-cross-entropy=1.000526
# 2019-11-30 11:50:59,996 [INFO]  Epoch[24] Train-bldng_us-accuracy=0.705720
# 2019-11-30 11:50:59,996 [INFO]  Epoch[24] Time cost=2.018
# 2019-11-30 11:51:00,006 [INFO]  Saved checkpoint to "imputer_model\model-0024.params"
# 2019-11-30 11:51:00,157 [INFO]  Epoch[24] Validation-cross-entropy=1.077213
# 2019-11-30 11:51:00,158 [INFO]  Epoch[24] Validation-bldng_us-accuracy=0.674623
# 2019-11-30 11:51:01,313 [INFO]  Epoch[25] Batch [0-886]	Speed: 12316.58 samples/sec	cross-entropy=1.015253	bldng_us-accuracy=0.697999
# 2019-11-30 11:51:02,386 [INFO]  Epoch[25] Train-cross-entropy=0.999898
# 2019-11-30 11:51:02,388 [INFO]  Epoch[25] Train-bldng_us-accuracy=0.705508
# 2019-11-30 11:51:02,389 [INFO]  Epoch[25] Time cost=2.230
# 2019-11-30 11:51:02,396 [INFO]  Saved checkpoint to "imputer_model\model-0025.params"
# 2019-11-30 11:51:02,559 [INFO]  Epoch[25] Validation-cross-entropy=1.074316
# 2019-11-30 11:51:02,561 [INFO]  Epoch[25] Validation-bldng_us-accuracy=0.675565
# 2019-11-30 11:51:03,689 [INFO]  Epoch[26] Batch [0-886]	Speed: 12613.70 samples/sec	cross-entropy=1.010450	bldng_us-accuracy=0.698281
# 2019-11-30 11:51:04,743 [INFO]  Epoch[26] Train-cross-entropy=0.998223
# 2019-11-30 11:51:04,745 [INFO]  Epoch[26] Train-bldng_us-accuracy=0.706073
# 2019-11-30 11:51:04,747 [INFO]  Epoch[26] Time cost=2.184
# 2019-11-30 11:51:04,757 [INFO]  Saved checkpoint to "imputer_model\model-0026.params"
# 2019-11-30 11:51:04,925 [INFO]  No improvement detected for 5 epochs compared to 1.0712494233145786 last error obtained: 1.0759129973512198, stopping here
# 2019-11-30 11:51:04,927 [INFO]
# ========== done (66.64500188827515 s) fit model
# C:\Users\user\Anaconda3\lib\site-packages\datawig\calibration.py:92: RuntimeWarning: divide by zero encountered in log
#   return np.log(probas)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# ### 2) using fancyimpute
#
# https://pypi.org/project/fancyimpute/

# %%
from fancyimpute import SoftImpute
import pandas as pd

class SoftImputeDf(SoftImpute):
    """DataFrame Wrapper around SoftImpute"""

    def __init__(self, shrinkage_value=None, convergence_threshold=0.001,
                 max_iters=100,max_rank=None,n_power_iterations=1,init_fill_method="zero",
                 min_value=None,max_value=None,normalizer=None,verbose=True):

        super(SoftImputeDf, self).__init__(shrinkage_value=shrinkage_value, 
                                           convergence_threshold=convergence_threshold,
                                           max_iters=max_iters,max_rank=max_rank,
                                           n_power_iterations=n_power_iterations,
                                           init_fill_method=init_fill_method,
                                           min_value=min_value,max_value=max_value,
                                           normalizer=normalizer,verbose=False)



    def fit_transform(self, X, y=None):

        assert isinstance(X, pd.DataFrame), "Must be pandas dframe"

        for col in X.columns:
            if X[col].isnull().sum() < 10:
                X[col].fillna(0.0, inplace=True)

        z = super(SoftImputeDf, self).fit_transform(X.values)
        df = pd.DataFrame(z, index=X.index, columns=X.columns)
        cats = list(X.select_dtypes(include='category'))
        df[cats] = df[cats].astype('category')

        # return pd.DataFrame(z, index=X.index, columns=X.columns)
        return df

# %%
SoftImputeDf(train)
# Out:
# SoftImputeDf(convergence_threshold=0.001, fill_method='zero', max_iters=100, max_rank=None, max_value=None, min_value=None, n_power_iterations=1, normalizer=None, verbose=False)
